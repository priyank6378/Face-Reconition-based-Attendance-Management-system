# %%
import dlib
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_faces_from_image_1(img):
    """Extract the faces from the image:
        returns : list of faces , image with bounding box on faces
        list of faces : are ready for input to the learning model just adjust the INPUT_SHAPE
    """
    detector = dlib.cnn_face_detection_model_v1('./mmod_human_face_detector.dat')
#     detector = dlib.get_frontal_face_detector()
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = detector(gray_img)
    cropped_faces = []
    take = 7  # increase the size of the bounding box
    for face in faces:
        cropped_faces.append(img[ face.rect.top()-take :face.rect.bottom()+take, face.rect.left()-take:face.rect.right()+take , :].copy())
    return cropped_faces

def get_faces_from_image_2(img):
    detector = dlib.get_frontal_face_detector()
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = detector(gray_img)
    cropped_faces = []
    take = 7  # increase the size of the bounding box
    for face in faces:
        cropped_faces.append(img[ face.top()-take :face.bottom()+take, face.left()-take:face.right()+take , :].copy())
    return cropped_faces

# %%
data_dir = r"E:\semester 5\mini project\face recognition algorithms\data"
names = dict([(v,k) for k,v in enumerate(os.listdir(data_dir))])

# %%
names
# Out:
# {'Hrishi': 0, 'Jenil': 1, 'saurabh': 2, 'shyam': 3, 'Tomar': 4}

# %%
X = []
y = []
for name,index in names.items():
    for file in os.listdir(data_dir+'\\'+name):
        img = cv2.imread(data_dir+'\\'+name+'\\'+file)
        face = get_faces_from_image_2(img)
        if (len(face)):
            for f in face:
                X.append(f)
                y.append(index)
# Out:
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction
# Rotate image to clock direction
# Rotate to inverse clock direction
# Rotate to inverse clock direction

# %%
ind = 3
print(y[ind])
plt.imshow(X[ind][:,:,::-1])
# Out:
# 0

# %%
target_dir = r"E:\semester 5\mini project\face recognition algorithms\dataset"
os.makedirs(target_dir)

# %%
for name in names.keys():
    os.makedirs(target_dir+'\\'+name)

# %%
target_dirs = [target_dir+'\\'+name for name in names]

# %%
rev_names = dict([(v,k) for k,v in names.items()])
rev_names
# Out:
# {0: 'Hrishi', 1: 'Jenil', 2: 'saurabh', 3: 'shyam', 4: 'Tomar'}

# %%
for i in range(len(X)):    
    if np.product(X[i].shape):
        print(target_dirs[y[i]]+'\\'+str(i)+'.jpg')
        cv2.imwrite(target_dirs[y[i]]+'\\'+str(i)+'.jpg', X[i])
# Out:
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\0.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\1.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\2.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\3.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\4.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\5.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\6.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\7.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\8.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\9.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\10.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\11.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\12.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Hrishi\13.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\14.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\15.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\16.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\17.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\18.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\19.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\20.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\21.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\22.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\23.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\24.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\25.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\26.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\27.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\28.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\29.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\30.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\31.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\32.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\33.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Jenil\34.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\35.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\36.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\37.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\38.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\39.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\40.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\41.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\42.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\43.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\44.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\45.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\46.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\47.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\48.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\49.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\50.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\51.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\52.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\53.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\54.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\55.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\56.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\57.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\58.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\59.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\60.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\61.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\62.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\63.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\64.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\65.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\saurabh\66.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\shyam\67.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\shyam\68.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\shyam\69.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\shyam\70.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\shyam\71.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\shyam\72.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\shyam\73.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\74.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\75.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\76.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\77.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\78.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\79.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\80.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\81.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\82.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\83.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\84.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\85.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\86.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\87.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\88.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\89.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\90.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\91.jpg
# E:\semester 5\mini project\face recognition algorithms\dataset1\Tomar\92.jpg
